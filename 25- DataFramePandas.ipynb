# %%
import pandas as pd
import numpy as np

# %%
my_data = np.array ([[10,20,30] , [20,30,40], [20,50,10], [10,15,20]])

# %%
my_data
# Out:
# array([[10, 20, 30],
#        [20, 30, 40],
#        [20, 50, 10],
#        [10, 15, 20]])

# %%
my_name = ["Lewis" , "Yusuf_Ali", "Max", "James"]

# %%
my_colmuns = ["Jan", "Feb", "Mar"]

# %%
my_data_frame = pd.DataFrame(my_data)

# %%
my_data_frame
# Out:
#     0   1   2
# 0  10  20  30
# 1  20  30  40
# 2  20  50  10
# 3  10  15  20

# %%
type(my_data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
my_data_frame[1]
# Out:
# 0    20
# 1    30
# 2    50
# 3    15
# Name: 1, dtype: int64

# %%
new_data_frame = pd.DataFrame(my_data, index=my_name, columns=my_colmuns)

# %%
new_data_frame
# Out:
#            Jan  Feb  Mar
# Lewis       10   20   30
# Yusuf_Ali   20   30   40
# Max         20   50   10
# James       10   15   20

# %%
new_data_frame["Feb"]
# Out:
# Lewis        20
# Yusuf_Ali    30
# Max          50
# James        15
# Name: Feb, dtype: int64

# %%
type(new_data_frame["Feb"])
# Out:
# pandas.core.series.Series

# %%
feb_series = new_data_frame["Feb"]

# %%
feb_series.mean()
# Out:
# np.float64(28.75)

# %%
feb_series.Lewis
# Out:
# np.int64(20)

# %%
feb_series.Yusuf_Ali
# Out:
# np.int64(30)

# %%
feb_series.max()
# Out:
# 50

# %%
new_data_frame["Jan"].mean()
# Out:
# np.float64(15.0)

# %%
new_data_frame
# Out:
#            Jan  Feb  Mar
# Lewis       10   20   30
# Yusuf_Ali   20   30   40
# Max         20   50   10
# James       10   15   20

# %%
new_data_frame[["Jan","Feb"]]
# Out:
#            Jan  Feb
# Lewis       10   20
# Yusuf_Ali   20   30
# Max         20   50
# James       10   15

# %%
new_data_frame.loc["Lewis"]
# Out:
# Jan    10
# Feb    20
# Mar    30
# Name: Lewis, dtype: int64

# %%
type(new_data_frame.loc["Lewis"])
# Out:
# pandas.core.series.Series

# %%
new_data_frame.loc["Lewis"].mean()
# Out:
# np.float64(20.0)

# %%
new_data_frame.iloc[3]
# Out:
# Jan    10
# Feb    15
# Mar    20
# Name: James, dtype: int64

# %%
new_data_frame["Apr"] = new_data_frame["Mar"] * 2

# %%
new_data_frame
# Out:
#            Jan  Feb  Mar  Apr
# Lewis       10   20   30   60
# Yusuf_Ali   20   30   40   80
# Max         20   50   10   20
# James       10   15   20   40

# %%
# axis=0    ------>    row
# axis=1    ------>    colums


new_data_frame.drop("Lewis", axis = 0)
# Out:
#            Jan  Feb  Mar  Apr
# Yusuf_Ali   20   30   40   80
# Max         20   50   10   20
# James       10   15   20   40

# %%
new_data_frame.drop("Mar", axis=1)
# Out:
#            Jan  Feb  Apr
# Lewis       10   20   60
# Yusuf_Ali   20   30   80
# Max         20   50   20
# James       10   15   40

# %%
new_data_frame
# Out:
#            Jan  Feb  Mar  Apr
# Lewis       10   20   30   60
# Yusuf_Ali   20   30   40   80
# Max         20   50   10   20
# James       10   15   20   40

# %%
# inplace  ---> icinde yap demektir ve true ise evet der ve o matrix oyle kaydedilir
new_data_frame.drop("Mar", axis=1, inplace=True)

# %%
new_data_frame
# Out:
#            Jan  Feb  Apr
# Lewis       10   20   60
# Yusuf_Ali   20   30   80
# Max         20   50   20
# James       10   15   40

# %%
new_data_frame["Jan"].Lewis
# Out:
# np.int64(10)

# %%
new_data_frame["Jan"]["Lewis"]
# Out:
# np.int64(10)

# %%
new_data_frame
# Out:
#            Jan  Feb  Apr
# Lewis       10   20   60
# Yusuf_Ali   20   30   80
# Max         20   50   20
# James       10   15   40

# %%
boolean_frame = new_data_frame > 25

# %%
boolean_frame
# Out:
#              Jan    Feb    Apr
# Lewis      False  False   True
# Yusuf_Ali  False   True   True
# Max        False   True  False
# James      False  False   True

# %%
new_data_frame[boolean_frame]
# Out:
#            Jan   Feb   Apr
# Lewis      NaN   NaN  60.0
# Yusuf_Ali  NaN  30.0  80.0
# Max        NaN  50.0   NaN
# James      NaN   NaN  40.0

# %%
new_data_frame[new_data_frame > 30]
# Out:
#            Jan   Feb   Apr
# Lewis      NaN   NaN  60.0
# Yusuf_Ali  NaN   NaN  80.0
# Max        NaN  50.0   NaN
# James      NaN   NaN  40.0

# %%
new_data_frame[new_data_frame["Apr"] > 50]
# Out:
#            Jan  Feb  Apr
# Lewis       10   20   60
# Yusuf_Ali   20   30   80

# %%
new_data_frame
# Out:
#            Jan  Feb  Apr
# Lewis       10   20   60
# Yusuf_Ali   20   30   80
# Max         20   50   20
# James       10   15   40

# %%
new_data_frame.iloc[0]
# Out:
# Jan    10
# Feb    20
# Apr    60
# Name: Lewis, dtype: int64

# %%
new_data_frame.reset_index()
# Out:
#        index  Jan  Feb  Apr
# 0      Lewis   10   20   60
# 1  Yusuf_Ali   20   30   80
# 2        Max   20   50   20
# 3      James   10   15   40

# %%
new_data_frame
# Out:
#            Jan  Feb  Apr
# Lewis       10   20   60
# Yusuf_Ali   20   30   80
# Max         20   50   20
# James       10   15   40

# %%
new_data_frame["NewIndex"] = ["Ham", "Okc", "Alo", "Ver"]

# %%
new_data_frame
# Out:
#            Jan  Feb  Apr NewIndex
# Lewis       10   20   60      Ham
# Yusuf_Ali   20   30   80      Okc
# Max         20   50   20      Alo
# James       10   15   40      Ver

# %%
new_data_frame.set_index("NewIndex")
# Out:
#           Jan  Feb  Apr
# NewIndex
# Ham        10   20   60
# Okc        20   30   80
# Alo        20   50   20
# Ver        10   15   40

# %%
new_data_frame
# Out:
#            Jan  Feb  Apr NewIndex
# Lewis       10   20   60      Ham
# Yusuf_Ali   20   30   80      Okc
# Max         20   50   20      Alo
# James       10   15   40      Ver

# %%
new_data_frame.drop("NewIndex", axis = 1, inplace= True)

# %%
new_data_frame
# Out:
#            Jan  Feb  Apr
# Lewis       10   20   60
# Yusuf_Ali   20   30   80
# Max         20   50   20
# James       10   15   40
